# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
import pandas as pd
# Out:
# C:\Users\Pioneer2\AppData\Local\Temp\ipykernel_8208\1585676892.py:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\Pioneer2\AppData\Local\Temp\ipykernel_8208\1585676892.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
d=pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQi5lnVESmIFGng5PeZj2QYEM1hEcrGxmpTCidXkbHZmR-7eswXAsSqI0ZC02tdsJ5aTKzs56F_G0n7/pub?output=csv")

# %%
d.head()
# Out:
#        Name WorkOrder   Status Date Complete Time Complete Date Started  \
# 0      Alok     SHR17  Started    06/07/2023    6:41:59 PM   06/07/2023
# 1   fasfasf   fasfsfa  fasfaff           NaN           NaN          NaN
# 2  xcsxchgs   vhsvjvc   vjscvj           NaN           NaN          NaN
# 3    Devang     AHT32  Created    06/07/2023           NaN          NaN
# 4       Dev     SHR18  Started           NaN           NaN          NaN
#
#   Time Started Time Created Date Created Approx time to Complete  ...  \
# 0  12:41:59 PM   4:41:59 PM   06/05/2023                       1  ...
# 1          NaN          NaN          NaN                     NaN  ...
# 2          NaN          NaN          NaN                     NaN  ...
# 3          NaN          NaN          NaN                     NaN  ...
# 4          NaN          NaN          NaN                     NaN  ...
#
#   Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27  \
# ...

# %% [markdown]
# import dash
# import dash_core_components as dcc
# import dash_html_components as html
# import plotly.express as px
# import pandas as pd
#
# # create a Pandas dataframe
# df = pd.DataFrame({
#     "Date": ["2020-12-18", "2020-12-21", "2020-12-22", "2020-12-23", "2020-12-24"],
#     "Traded Qty": [29816205, 55160758, 51189571, 29056404, 28585509],
#     "Deliverable Qty": [5872798, 14528986, 10781372, 4792004, 6820426],
#     "Delivery %": [19.70, 26.34, 21.06, 16.49, 23.86],
#     "LTP": [268.15, 272.00, 253.85, 258.20, 263.75],
#     "Open Interest": [73110000, 71454000, 71013000, 67350000, 68697000]
# })
#
# # create a scatter plot with hover text
# fig = px.scatter(df, x="Deliverable Qty", y="Open Interest", hover_data=["Delivery %"])
# fig.update_traces(mode='markers')
#
# # create a Dash app
# app = dash.Dash(__name__)
#
# # define the layout
# app.layout = html.Div(children=[
#     html.H1(children='Interactive Dashboard'),
#     dcc.Graph(
#         id='example-graph',
#         figure=fig
#     )
# ])
#
# if __name__ == '__main__':
#     app.run_server()

# %% [markdown]
# #### Making the code 13  June 2023

# %%
df=pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQi5lnVESmIFGng5PeZj2QYEM1hEcrGxmpTCidXkbHZmR-7eswXAsSqI0ZC02tdsJ5aTKzs56F_G0n7/pub?output=csv")

# %%
df.head()
# Out:
#        Name WorkOrder   Status Date Complete Time Complete Date Started  \
# 0      Alok     SHR17  Started    06/07/2023    6:41:59 PM   06/07/2023
# 1   fasfasf   fasfsfa  fasfaff           NaN           NaN          NaN
# 2  xcsxchgs   vhsvjvc   vjscvj           NaN           NaN          NaN
# 3    Devang     AHT32  Created    06/07/2023           NaN          NaN
# 4       Dev     SHR18  Started           NaN           NaN          NaN
#
#   Time Started Time Created Date Created Approx time to Complete  ...  \
# 0  12:41:59 PM   4:41:59 PM   06/05/2023                       1  ...
# 1          NaN          NaN          NaN                     NaN  ...
# 2          NaN          NaN          NaN                     NaN  ...
# 3          NaN          NaN          NaN                     NaN  ...
# 4          NaN          NaN          NaN                     NaN  ...
#
#   Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27  \
# ...

# %%
df.columns
# Out:
# Index(['Name', 'WorkOrder', 'Status', 'Date Complete', 'Time Complete',
#        'Date Started', 'Time Started', 'Time Created', 'Date Created',
#        'Approx time to Complete', 'Site ', 'Description', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31'],
#       dtype='object')

# %%
site_values= df['Site '].unique()

# %%
print(site_values)
# Out:
# ['Elmira- Home/Shop' nan 'Break' '12:31:42 PM' '1:06:36 PM' '1:09:46 PM'
#  '2:39:53 PM' '5:21:43 PM']

# %%
## making a dropdown with all the sites

##selection box using all the unique values in site

site = selectbox(" Our Sites: ", site_values)
 
# print the selected hobby
print("Your selected site is : ", site)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 ## making a dropdown with all the sites
#       2
#       3 ##selection box using all the unique values in site
# ----> 5 site = selectbox(" Our Sites: ", site_values)
#       7 # print the selected hobby
#       8 print("Your selected site is : ", site)
#
# NameError: name 'selectbox' is not defined

# %%
### I am creating a table where the site is selected site and having workorder/ priorty /name/ status and Date started as a column for each



def filter_by_site(df, selected_site):
    filtered_df = df[df['Site '] == selected_site]  
    return filtered_df[['WorkOrder', 'Name', 'Status', 'Date Started']] 


#selected_site = 'Break' 

filtered_table = filter_by_site(df, site)

# %%
# create a pie chart at the order


df.groupby(['Status']).sum().plot(kind='pie', y='Name')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 # create a pie chart at the order
# ----> 4 df.groupby(['Status']).sum().plot(kind='pie', y='Name')
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:70, in plot(data, kind, **kwargs)
#      68             ax = plt.gca()
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      71 plot_obj.generate()
#      72 plot_obj.draw()
#
# ...

# %%
##
def filter_by_site(df, status):
    filtered_df = df[df['Status'] == selected_site]  
    return filtered_df[['WorkOrder', 'Name', 'Status', 'Date Started']]

# %%
## I am ploting a pie chart for th column name (Status) to look for the how much percentage of works are either completed, Started or Completed



import pandas as pd
import matplotlib.pyplot as plt



status_counts = df['Status'].value_counts()


status_pie =plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%' )


plt.title('Status Distribution')

plt.show()

# %%
print( df[df['Status'] == 'Created'] )
# Out:
#      Name WorkOrder   Status Date Complete Time Complete Date Started  \
# 3  Devang     AHT32  Created    06/07/2023           NaN          NaN
#
#   Time Started Time Created Date Created Approx time to Complete  ...  \
# 3          NaN          NaN          NaN                     NaN  ...
#
#   Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27  \
# 3         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31
# 3         NaN         NaN         NaN         NaN
#
# [1 rows x 32 columns]

# %%
### looking for the higest priority task and name of the people who is it assignned for
list=[]
list=df['WorkOrder']

# %%
#print(list)


list.to_string()
# Out:
# '0            SHR17\n1          fasfsfa\n2          vhsvjvc\n3            AHT32\n4              NaN\n5              NaN\n6              NaN\n7              NaN\n8              NaN\n9              NaN\n10             NaN\n11             NaN\n12             NaN\n13             NaN\n14             NaN\n15             NaN\n16             NaN\n17             NaN\n18             NaN\n19             NaN\n20             NaN\n21             NaN\n22             NaN\n23             NaN\n24             NaN\n25             NaN\n26             NaN\n27             NaN\n28             NaN\n29             NaN\n30             NaN\n31             NaN\n32             NaN\n33             NaN\n34             NaN\n35             NaN\n36             NaN\n37      06/12/2023\n38           AMC40\n39            Ben3\n40             NaN\n41             NaN\n42             NaN\n43             NaN\n44             NaN\n45             NaN\n46             NaN\n47    Ben Tennyson\n48         Stopped\n49           Chri
# ...

# %%
for i in list:
    i.to_string()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 for i in list:
# ----> 2     i.to_string()
#
# AttributeError: 'str' object has no attribute 'to_string'

# %%
for i in list:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
df['Work_with_high_priority'] = df['WorkOrder'].dropna().apply(lambda x: x.startswith(('AH', 'SH')))

print(df['Work_with_high_priority'])
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN
# 33      NaN
# 34      NaN
# 35      NaN
# 36      NaN
# 37    False
# 38    False
# 39    False
# 40      NaN
# 41      NaN
# 42      NaN
# 43      NaN
# 44      NaN
# 45      NaN
# 46      NaN
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# Name: Work_with_high_priority, dtype: object

# %%
# def priority_table(df):
#     if df['WorkOrder'].dropna().apply(lambda x: x.startswith(('AH', 'SH'))):
#         return df[['WorkOrder', 'Name','Site ']]
    
    
def priority_table(df, selected_value):
    filtered_df = df[df['Work_with_high_priority'] == selected_value and (df['Status'] == 'created')]  
    return filtered_df[['WorkOrder', 'Name', 'Status']]     


priority_table(df, True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 11
#       7     filtered_df = df[df['Work_with_high_priority'] == selected_value and (df['Status'] == 'created')]
#       8     return filtered_df[['WorkOrder', 'Name', 'Status']]
# ---> 11 priority_table(df, True)
#
# Cell In[21], line 7, in priority_table(df, selected_value)
#       6 def priority_table(df, selected_value):
# ----> 7     filtered_df = df[df['Work_with_high_priority'] == selected_value and (df['Status'] == 'created')]
#       8     return filtered_df[['WorkOrder', 'Name', 'Status']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
# ...

# %%
def priority_table(df):
    condition = df['WorkOrder'].dropna().apply(lambda x: x.startswith(('AH', 'SH')))
    condition = condition.reset_index(drop=True)
    if condition.any():
        return df.loc[condition, ['WorkOrder', 'Name', 'Site ']]

priority_table(df)
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[22], line 7
#       4     if condition.any():
#       5         return df.loc[condition, ['WorkOrder', 'Name', 'Site ']]
# ----> 7 priority_table(df)
#
# Cell In[22], line 5, in priority_table(df)
#       3 condition = condition.reset_index(drop=True)
#       4 if condition.any():
# ----> 5     return df.loc[condition, ['WorkOrder', 'Name', 'Site ']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# ...

# %%
 filtered_df = df[(df['Work_with_high_priority'] == selected_value) ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 filtered_df = df[(df['Work_with_high_priority'] == selected_value) ]
#
# NameError: name 'selected_value' is not defined

# %%
## I am creating a list of 10 values of people have assigned the heigest priotiy
#creatin a column with high priority work
df['Work_with_high_priority'] = df['WorkOrder'].dropna().apply(lambda x: x.startswith(('AH','SH','AM','SM'))) 

print(df['Work_with_high_priority'])    
def priority_table(df, selected_value):
    filtered_df = df[df['Work_with_high_priority'] == selected_value ]
    
    #filtered_data= filtered_df[[ 'Name', 'Status']]
    #filtered_df2=filtered_df[filtered_df[['Status']]=='Created']
        #print(filtered_df[['Status']])
    df2=filtered_df[[ 'Name', 'Status']]    
    df2=(df2[df2['Status'] =='Created'])
    
    
    return df2


priority_table(df, True)
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# 30      NaN
# 31      NaN
# 32      NaN
# 33      NaN
# 34      NaN
# 35      NaN
# 36      NaN
# 37    False
# 38     True
# 39    False
# 40      NaN
# 41      NaN
# 42      NaN
# 43      NaN
# 44      NaN
# 45      NaN
# 46      NaN
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# Name: Work_with_high_priority, dtype: object
#      Name   Status
# 0    Alok  Created
# 3  Devang  Created

# %%
# Head count of workers

#worker working on farm right now in each site if they loggedin
from datetime import date
from datetime import datetime
today=date.today()
todays_date = today.strftime("%m/%d/%Y")
print(todays_date)
now = datetime.now()
current_time = now.strftime("%I:%M %p ")

print(current_time)
# Out:
# 06/20/2023
# 02:25 PM

# %%
## looking for workers at each farm

# # Numer of sites
# site_values= df['Site '].unique()
# site_numbers=len(site_values)


# ## seeing how many employes at each farm 
# print("Workers right now")

# # roll_no = [10, 20, 30, 40, 50]
# # names = ['Ramesh', 'Mahesh', 'Kamlesh',
# #          'Suresh', 'Dinesh']
 
# # students = dict(zip(roll_no, names))
# # print(students)
# sites=[]
# counts=[]

# # def workers_rn(data):
# for i in site_values:
#     df_filter=df[df['Site ']==i]
#     #print(i)
#     sites.append(i)
#     print(df_filter['Name'])
#     c=df_filter[df_filter['Status']=="Started"]
#     sum=c['Name'].count()            
#     counts.append(sum)
    
# working_rightnow=dict(zip(sites,counts))
# print(working_rightnow)
    
        
    
        
    
    
# Get unique site values
site_values = df['Site '].unique()

# Count the number of sites
site_numbers = len(site_values)

print("Workers right now")

# Initialize empty lists
sites = []
counts = []

# Iterate over each site value
for site in site_values:
    # Filter the dataframe for the current site
    df_filter = df[df['Site '] == site]
    
    # Append the site value to the 'sites' list
    sites.append(site)
    
    # Print the names of workers at the current site
    #print(df_filter[['Name','Site ']])
    
    # Count the number of workers with 'Status' as 'Started'
    c = df_filter[df_filter['Status'] == "Started"]['Name'].count()
    print(c)
    
    # Append the count to the 'counts' list
    counts.append(c)

# Create a dictionary mapping sites to worker counts
working_rightnow = dict(zip(sites, counts))
print(working_rightnow)


# print(sites)
# print(counts)
# Out:
# Workers right now
# 2
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# {'Elmira- Home/Shop': 2, nan: 0, 'Break': 0, '12:31:42 PM': 0, '1:06:36 PM': 0, '1:09:46 PM': 0, '2:39:53 PM': 0, '5:21:43 PM': 0}

# %%
print(sites)
# Out:
# ['Elmira- Home/Shop', nan, 'Break', '12:31:42 PM', '1:06:36 PM', '1:09:46 PM', '2:39:53 PM', '5:21:43 PM']

# %%
print(counts)
# Out:
# [1, 0, 1, 1, 1, 1, 1]

# %%
# working hours today
# for each employe working today

## filter who is working all has been working last day
# Head count of workers

from datetime import date,timedelta

today=date.today()

print(today)

previous_day= today - timedelta(days=1)

print(previous_day)
todays_date = today.strftime("%m/%d/%Y")
print(todays_date)


previous_date=previous_day.strftime("%m/%d/%Y")

print(previous_date)
# Out:
# 2023-06-20
# 2023-06-19
# 06/20/2023
# 06/19/2023

# %%
df=pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQSjwmOOwc1iHvIl_gc1mlUB9Pa_rB7pwg__Agq7JQowZ8XvycnGG2AxsXyk9WDJ4h_clBt0jiceTDl/pub?output=csv")

# %%
df.head()
# Out:
#      Name  Work Order     Status            Description                  Site  \
# 0    Test2       AHT2    Created               Testing3  Sutter- Huller/Dryer
# 1   Devang       AHC3  Completed                Testing     Dixon- Home Piece
# 2  Atharva       AHR4    Created       Description test   Rio Oso- Home/ Shop
# 3    Test3       AHT3  Completed              completed  Sutter- Huller/Dryer
# 4  Tester1       ALC6     Paused  Testing the date time     Dixon- East Block
#
#   Date Created Time Created Assigned Hours  Duration1       Date1  Duration2  \
# 0   06/20/2023   3:22:19 PM              3        NaN         NaN        NaN
# 1   06/20/2023   3:26:02 PM              5        5.0  06/20/2023        3.0
# 2   06/20/2023   3:30:27 PM              3        5.0  06/20/2023        NaN
# 3   06/21/2023   1:20:53 PM              6        4.0  06/20/2023        1.0
# 4   06/21/2023   1:32:16 PM              2        NaN         NaN        NaN
#
# ...

# %%
df.columns
# Out:
# Index(['Name ', 'Work Order', 'Status', 'Description', 'Site', 'Date Created',
#        'Time Created', 'Assigned Hours', 'Duration1', 'Date1', 'Duration2',
#        'Date2', 'Duration3', 'Date3', 'Duration4 ', 'Date4 ', 'Duration5 ',
#        'Date5 '],
#       dtype='object')

# %%
# if the status is completed and the last date is pervous date then add all the duration in the hours count for each  person

from datetime import date,timedelta
today=date.today()
#print(today)
previous_day= today - timedelta(days=1)
previous_date=previous_day.strftime("%m/%d/%Y")
print(previous_date)



pervious_work=df[df['Date1']=='previous_date']
compled_work[['Name','WorkOrder']]

# # Get the previous day's date
# previous_day = date.today() - timedelta(days=1)
# previous_day_str = previous_day.strftime("%m/%d/%Y")

# #compl
# # print(previous_date)

# # df hours_count(df):
# #     df_filter=df[df[name]]

# # Filter the dataframe for the previous day's entries
# previous_day_df = df[df['Date Created'] == previous_day_str]

# # Create an empty dictionary to store names and total hours
# worker_hours = {}

# # Iterate over the filtered dataframe
# for index, row in previous_day_df.iterrows():
#     name = row["Name"]
#     total_hours = 0
    
#     # Iterate over the columns containing durations
#     for i in range(1, 6):  # Assuming you have 5 pairs of duration and date columns
#         duration_col = f"Duration{i}"
#         date_col = f"Date{i}"
        
#         duration = row[duration_col]
#         date = row[date_col]
        
#         if pd.notnull(duration) and date == previous_day_str:
#             total_hours += duration
    
#     # Add the worker's total hours to the dictionary
#     if total_hours > 0:
#         worker_hours[name] = total_hours

# # Print the names and total hours
# for name, hours in worker_hours.items():
    
for i in range (1,6):
    date_col = f"Date{i}"
    print(date_col)
    df2= df[date_col]=='previous_date'
    print(df2)
    #date_col = f"Duration{i}"
    #print(date_col)
# Out:
# 06/20/2023
# Date1
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Date1, dtype: bool
# Date2
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Date2, dtype: bool
# Date3
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Date3, dtype: bool
# Date4
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
#out of which i want to figer out name of people who worked yesterday and how many hours they worked yesterday. below is the example how my dataset looks like


import pandas as pd
from datetime import date, timedelta

# Read the CSV file


# Get the previous day's date
previous_day = date.today() - timedelta(days=1)
previous_day_str = previous_day.strftime("%m/%d/%Y")

# Create an empty dictionary to store names and total hours
worker_hours = {}

# Iterate over the columns containing dates and durations
for i in range(1, 6): 
    date_col = f"Date{i}"
    duration_col = f"Duration{i}"
    
    try:
       
        df_filtered = df[df[date_col] == previous_day_str]
        
        # Calculate the total hours for each worker
        for index, row in df_filtered.iterrows():
            name = row['Name ']
            duration = row[duration_col]
            
            if pd.notnull(duration):
                if name in worker_hours:
                    worker_hours[name] += float(duration)
                else:
                    worker_hours[name] = float(duration)
    except KeyError:
        # Skip the iteration if the date column does not exist
        continue

# Print the names and total hours
for name, hours in worker_hours.items():
    print(f"{name}: {hours} hours")
# Out:
# Devang: 8.0 hours
# Atharva: 5.0 hours
# Test3: 5.0 hours

# %%
# get all the date in previous week 
from datetime import datetime
today = datetime.today()
last_sunday = today - timedelta(days=today.weekday() + 1)
last_sunday=last_sunday.strftime("%m/%d/%Y")
last_monday = last_sunday - timedelta(days=6)
last_monday=last_monday.strftime("%m/%d/%Y")
print(last_sunday)
print(last_monday)
# Out:
# 2023-06-18 17:21:18.322818
# 2023-06-12 17:21:18.322818

# %%
from dateutil.relativedelta import relativedelta, MO,SU

# getting today's current local date
todayDate = date.today()

todayDate1=todayDate.strftime("%m/%d/%Y")
print('Today Date:',todayDate1)


lastMonday = todayDate + relativedelta(weekday=MO(-2))
lastMonday1=lastMonday.strftime("%m/%d/%Y")
# printing the last Monday date
print("The last Monday date:", lastMonday1)

lastSunday=todayDate + relativedelta(weekday=SU(-1))
lastSunday=lastSunday.strftime("%m/%d/%Y")
print("last sunday was ", lastSunday)
# Out:
# Today Date: 06/21/2023
# The last Monday date: 06/12/2023
# last sunday was  06/18/2023

# %%
import pandas as pd
from datetime import datetime, timedelta
 


today = datetime.today()
last_sunday = today - timedelta(days=today.weekday() + 1)
last_monday = last_sunday - timedelta(days=6)


worker_hours = {}

for i in range(1, 6):
    date_col = f"Date{i}"
    duration_col = f"Duration{i}"
    
    try:
        # Filter the dataframe for the previous week's entries
        df_filtered = df2[(df2[date_col] >= last_monday.strftime("%m/%d/%Y")) & (df2[date_col] <= last_sunday.strftime("%m/%d/%Y"))]
        
        # Calculate the total hours for each worker
        for index, row in df_filtered.iterrows():
            name = row['Name']
            duration = row[duration_col]
            
            if pd.notnull(duration):
                if name in worker_hours:
                    worker_hours[name] += float(duration)
                else:
                    worker_hours[name] = float(duration)
    except KeyError:
        # Skip the iteration if the date column does not exist
        continue

# Display the names and total hours as a table using Streamlit
for name, hours in worker_hours.items():
    print(f"{name}: {hours} hours")
